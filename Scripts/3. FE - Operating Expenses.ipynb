# %% [markdown]
# # Operating Expenses
#
# The Single Territorial Form (FUT) reduce the number of basic official data reports to be submitted to the National Government, the Departments, Districts and Municipalities, their public establishments, the Territories and certified Indigenous Reservations and/or Associations of the latter, referred to in Decree 1953 of 2014 or the rule that amends, adds or replaces it. Likewise, the FUT shall promote the simplification and improvement of the quality of such reports to be informed. In this regard, no entity of the National Government may, on its own account, request from the entities obliged to report to the FUT the information that they are already reporting through it.
#
# One of the most important FUT categories is operating expenses.
#
# **Entity:** Contaduría General de la Nación
#
# **Description:** Historical information (2012-2021) of the operating expenses of the country's
# municipalities.
#
# **Variables**
#
# 1. FUT code - int -
# 2. Entity name - string - name of the territorial entity
# 3. DANE department code - int - code that assigns the DANE to each department
# 4. Name DANE department - string - department name
# 5. DANE code municipality - int - code that assigns the DANE to each municipality
# 6. Name DANE municipality - string - name of the municipality
# 7. Concept Code - string - code that is assigned to each concept
# 8. Concept - string - name of each income received by the territorial entity
# 9. Executing Unit Code - int -
# 10. Executing Unit - string -
# 11. Initial Budget - float - initial budget projected by the territorial entity for each concept
# 12. Final Budget - float - budget at the end of the year
# 13. Commitments - float - total revenue collected
# 14. Obligations - float - total value of the commitments contracted into by the territorial entity
# 15. Payments - float - total value intended to pay the obligations
#
# For more information click [here](https://www.chip.gov.co/schip_rt/paginiciofut.htm).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Data Overview

# %% [markdown]
# The data is separated into different csv's by year from 2012 to 2021, so it is necessary to merge them in order to process and clean them all together at the same time.

# %%
# %%capture 
## Add the capture line to eliminate warning messages
## A list containing the years 2012 to 2021 is created.
years = list(range(2013, 2022))

## Start by loading the dataset of operating cats for the year 2012.
df = pd.read_csv('FUT_GASTOS_FUNCIONAMIENTO_2012.csv', sep = ";",error_bad_lines=False, encoding = 'utf-8')

## A special column is created to contain the year to which each DataSet belongs.
df['Año'] = 2012

## To concatenate the data, an auxiliary dataframe will be created and updated with the data for each year.
## to be appended to the initial DataFrame.
for year in years:
    aux_df =  pd.read_csv('FUT_GASTOS_FUNCIONAMIENTO_'+ str(year) +'.csv', sep = ";",error_bad_lines=False, encoding = 'utf-8')
    aux_df['Año'] = year
    df = pd.concat([df, aux_df], axis = 0)

## Reset the index to remove the levels generated by the concatenation.
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# We found that the complete DataSet of running cats contains almost 2 million individuals and 18 variables.

# %%
df.shape
# Out:
# (1927006, 18)

# %% [markdown]
# Whose first 5 individuals look as follows.

# %%
df.head()
# Out:
#    Código FUT                                     Nombre Entidad  \
# 0   115050000                              DEPARTAMENTO DEL META
# 1   117373000                            DEPARTAMENTO DEL TOLIMA
# 2   118181000                            DEPARTAMENTO DEL ARAUCA
# 3   118888000  DEPARTAMENTO DEL ARCHIPIÉLAGO DE SAN ANDRÉS, P...
# 4   110505000                          DEPARTAMENTO DE ANTIOQUIA
#
#    Cód. DANE Departamento                           Nombre DANE Departamento  \
# 0                      50                                               META
# 1                      73                                             TOLIMA
# 2                      81                                             ARAUCA
# 3                      88  ARCHIPIÉLAGO DE SAN ANDRÉS, PROVIDENCIA Y SANT...
# 4                       5                                          ANTIOQUIA
#
#    Cód. DANE Municipio Nombre DANE Municipio Código Concepto  \
# 0                  NaN                   NaN           1.1.1
# 1                  NaN                   NaN           1.1.1
# 2                  NaN                   NaN           1.1.1
# 3                  NaN                   NaN           1.1.1
# 4                  NaN                   NaN           1.1.1
#
#                                      Concepto  Código Unidad Ejecutora  \
# 0  SERVICIOS PERSONALES ASOCIADOS A LA NOMINA                      1.0
# 1  SERVICIOS PERSONALES ASOCIADOS A LA NOMINA                      1.0
# 2  SERVICIOS PERSONALES ASOCIADOS A LA NOMINA                      1.0
# 3  SERVICIOS PERSONALES ASOCIADOS A LA NOMINA                      1.0
# 4  SERVICIOS PERSONALES ASOCIADOS A LA NOMINA                      1.0
#
#          Unidad Ejecutora  Código Fuente Financiación Fuente Financiación  \
# 0  ADMINISTRACIÓN CENTRAL                         NaN                 NaN
# 1  ADMINISTRACIÓN CENTRAL                         NaN                 NaN
# 2  ADMINISTRACIÓN CENTRAL                         NaN                 NaN
# 3  ADMINISTRACIÓN CENTRAL                         NaN                 NaN
# 4  ADMINISTRACIÓN CENTRAL                         NaN                 NaN
#
#   Presupuesto Inicial Presupuesto Definitivo Compromisos Obligaciones  \
# 0          12.808.880             12.889.311  12.668.113   12.668.113
# 1           8.632.800              8.098.443   7.954.339    7.929.967
# 2           5.607.508              5.065.710   5.034.157    5.034.157
# 3          11.326.872             10.692.072   9.929.404    9.929.404
# 4          61.771.292             62.918.327  56.040.454   56.040.454
#
#         Pagos   Año
# 0  12.654.124  2012
# 1   7.924.443  2012
# 2   5.010.440  2012
# 3   9.929.404  2012
# 4  56.015.936  2012

# %% [markdown]
# As can be seen below, the size of the data reported each year has been increasing since 2012, so it is to be expected that the total cats for the last few years will be comparatively much larger than the first year if inflation is not taken into account. On the other hand, 2021 is the year with the lowest number of rows since these have not yet been reported.

# %%
df['Año'].value_counts()
# Out:
# 2020    215793
# 2018    214533
# 2017    214368
# 2019    213704
# 2016    211191
# 2014    207202
# 2015    206727
# 2013    204028
# 2012    196449
# 2021     43011
# Name: Año, dtype: int64

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# ### 2.1. Identifying unique concepts

# %% [markdown]
# The dataset inforamtion shows that does not have financial columns determined as numerical, therefore, among the steps to be performed will be the transformation of these columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1927006 entries, 0 to 1927005
# Data columns (total 18 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Código FUT                  int64
#  1   Nombre Entidad              object
#  2   Cód. DANE Departamento      int64
#  3   Nombre DANE Departamento    object
#  4   Cód. DANE Municipio         float64
#  5   Nombre DANE Municipio       object
#  6   Código Concepto             object
#  7   Concepto                    object
#  8   Código Unidad Ejecutora     float64
#  9   Unidad Ejecutora            object
#  10  Código Fuente Financiación  float64
#  11  Fuente Financiación         object
#  12  Presupuesto Inicial         object
#  13  Presupuesto Definitivo      object
#  14  Compromisos                 object
#  15  Obligaciones                object
#  16  Pagos                       object
#  17  Año                         int64
# dtypes: float64(3), int64(3), object(12)
# memory usage: 264.6+ MB

# %% [markdown]
# This dataset has different categories and subcategories, within which the categories with a lower level totalized the expenses and the budget of the categories of a higher level, as it can be seen there are 341 categories, Where the level of each category is given by the length of its chain, so category 1.2 is level 3 and totals the expenses and budget of categories 1.2.1, 1.2.2 which belong to the level 5 and other categories for example a level 7  1.2.2.1 category and so on.

# %%
len(df['Código Concepto'].unique())
# Out:
# 341

# %% [markdown]
# On the other hand, we have the columns that refer to territorial entities, concepts and executing units, the values in these columns must be standardized in such a way that, for example, the two or more ways of writing a department become a single form, accents and spaces must be eliminated.

# %%
columns_to_format = ['Nombre Entidad', 'Nombre DANE Departamento', 'Nombre DANE Municipio', 'Concepto', 'Unidad Ejecutora', 'Código Concepto']

# %% [markdown]
# As mentioned before, we will first remove the accents, the space at the begining and the end of ech string, and points by commas

# %%
a,b = 'áéíóúüñÁÉÍÓÚÜ','aeiouunAEIOUU'
trans = str.maketrans(a,b)
for column in columns_to_format:
    df[column] = df[column].str.strip()
    df[column] = df[column].str.translate(trans)
    df[column] = df[column].replace(r'\,','.', regex=True)

# %% [markdown]
# As can be seen for example the number of unique `Código Concepto` were recuded to only 187 categories.

# %%
len(df['Código Concepto'].unique())
# Out:
# 187

# %% [markdown]
# A special column is created to identify the length of the concept and all the sub concepts whose length in the code is greater than 5 are eliminated, this is done to avoid that the sub concepts are added again and alter the totalized results, in the same way it was decided to restrict the level of the analysis only up to 3 levels, therefore, the overall calculation of the expenses will not be affected if we remove those higher categories, in contrast, this filtering will help us to facilitate the analysis.

# %%
df['Nivel concepto'] = df['Código Concepto'].replace(r'\.','', regex=True)
df['Nivel concepto'] = df['Nivel concepto'].str.len()
#df = df[df['Nivel concepto'] <= 5]

# %%
df['Código Concepto'].unique()
# Out:
# array(['1.1.1', '1.1.3', '1.1.1.7', '1.1.4.1.1.1', '1.1.4.1.1.2',
#        '1.1.4.1.1.4', '1.1.4.1.1', '1.1.4.1', '1.1.4.1.1.3',
#        '1.1.4.2.1.1', '1.1.4.2.1.2', '1.1.4.2.1.4', '1.1.4.2.1',
#        '1.1.4.2', '1.1.4.2.1.3', '1.1.4.3.1', '1.1.4.3.2', '1.1.4.3.5',
#        '1.1.4.3', '1.1.4', '1.1', '1.1.4.3.3', '1.1.4.3.4', '1.2.1',
#        '1.2.2.12', '1.2.2.3', '1.2.2.3.2', '1.2.2.6', '1.2.2.8', '1.2.2',
#        '1.2', '1.3.4', '1.3.6.4', '1.3', '1.3.6', '1.3.8', '1.4', '1.9.2',
#        '1.9', '1', '1.9.1', '1.3.18', '1.1.1.9', '1.1.1.8', '1.1.1.7.1',
#        '1.1.3.1', '1.1.1.6', '1.1.1.5', '1.1.1.4', '1.1.1.3', '1.1.1.2',
#        '1.1.1.11', '1.1.1.10', '1.1.1.1', '1.1.2', '1.1.3.4', '1.1.3.3',
#        '1.1.3.2', '1.1.3.7', '1.1.3.6', '1.1.4.1.1.1.1', '1.1.4.1.1.2.1',
#        '1.1.4.1.1.1.4', '1.1.4.1.1.1.2', '1.1.4.1.1.3.1', '1.1.4.1.1.4.1',
#        '1.1.4.2.1.1.1', '1.1.4.2.1.1.2', '1.1.4.2.1.2.1', '1.1.4.2.1.1.4',
#        '1.1.4.2.1.3.1', '1.1.4.2.1.4.1', '1.1.4.3.1.1', '1.1.4.3.2.1',
#        '1.1.4.3.3.1', '1.1.4.3.4.1', '1.1.4.3.5.1', '1.10', '1.2.1.1',
#        '1.2.1.2', '1.2.2.1', '1.2.1.9', '1.2.2.11', '1.2.2.19',
#        '1.2.2.12.5', '1.2.2.12.2', '1.2.2.12.1', '1.2.2.2', '1.2.2.3.4',
#        '1.2.2.3.2.4', '1.2.2.3.3', '1.2.2.4', '1.2.2.3.5', '1.2.2.6.1',
#        '1.2.2.3.2.1', '1.2.2.3.2.3', '1.2.2.3.2.2', '1.2.2.3.1',
#        '1.2.2.5', '1.2.2.8.1', '1.2.2.6.5', '1.2.2.6.4', '1.2.2.6.3',
#        '1.2.2.6.2', '1.2.2.7', '1.2.2.8.3', '1.2.2.8.2', '1.2.2.9',
#        '1.2.9', '1.2.4', '1.3.1', '1.3.12', '1.3.11', '1.3.18.3',
#        '1.3.18.4', '1.3.15', '1.3.18.1', '1.3.18.2', '1.3.19', '1.3.14',
#        '1.3.2', '1.3.3', '1.3.6.1', '1.3.4.1', '1.3.4.2', '1.3.25',
#        '1.3.6.4.6', '1.3.6.7', '1.3.6.6', '1.3.6.5', '1.3.5', '1.3.6.4.4',
#        '1.3.6.4.1', '1.3.8.1', '1.3.8.2', '1.3.9', '1.4.1', '1.4.2',
#        '1.4.3', '1.9.1.1', '1.9.2.2', '1.8', '1.9.1.2', '1.9.2.1',
#        '1.9.2.3', '1.9.2.5', '1.9.2.8', 'VAL', '1.9.2.6', '1.9.4',
#        '1.9.2.4', '1.9.2.7', '1.9.3', '1.3.13', '1.1.4.3.2.2', '1.3.10',
#        '1.1.4.3.4.2', '1.1.4.3.3.2', '1.1.4.3.1.2', '1.1.4.2.1.3.2',
#        '1.1.4.2.1.4.2', '1.1.4.3.5.2', '1.1.3.5', '1.1.3.8',
#        '1.1.4.1.1.1.3', '1.1.4.1.1.2.2', '1.1.4.1.1.3.2', '1.1.4.1.1.4.2',
#        '1.1.4.2.1.1.3', '1.1.4.2.1.2.2', '1.3.7', '1.1.1.25', '1.1.1.14',
#        '1.1.1.12', '1.1.5', '1.2.2.3.2.9', '1.2.2.3.2.5', '1.3.12.1',
#        '1.3.12.2', '1.3.20', '1.3.6.1.2', '1.3.24', '1.3.6.1.1', '1.3.22',
#        '1.3.23', '1.3.6.7.10', '1.3.6.7.1'], dtype=object)

# %% [markdown]
# ### 2.2 Identifying other atypical formats

# %% [markdown]
# Below is a quick preview of the different categories in each of the previously mentioned columns.

# %%
for column in columns_to_format:
    print(column + '-------------------------------')
    print(df[column].unique())
# Out:
# Nombre Entidad-------------------------------
# ['DEPARTAMENTO DEL META' 'DEPARTAMENTO DEL TOLIMA'
#  'DEPARTAMENTO DEL ARAUCA' ... 'HATONUEVO' 'PUERTO RICO' 'YONDO']
# Nombre DANE Departamento-------------------------------
# ['META' 'TOLIMA' 'ARAUCA'
#  'ARCHIPIELAGO DE SAN ANDRES. PROVIDENCIA Y SANTA CATALINA' 'ANTIOQUIA'
#  'VICHADA' 'ATLANTICO' 'BOYACA' 'CAQUETA' 'CUNDINAMARCA' 'CESAR' 'CHOCO'
#  'MAGDALENA' 'NARIÑO' 'NORTE DE SANTANDER' 'SANTANDER' 'VALLE DEL CAUCA'
#  'PUTUMAYO' 'CASANARE' 'SUCRE' 'LA GUAJIRA' 'QUINDIO' 'AMAZONAS' 'GUAINIA'
#  'CORDOBA' 'VAUPES' 'BOLIVAR' 'CALDAS' 'CAUCA' 'HUILA' 'GUAVIARE'
#  'RISARALDA' 'BOGOTA. D.C.']
# Nombre DANE Municipio-------------------------------
# [nan 'BETEITIVA' 'SANTA MARIA' ... 'SAN JOSE DE CUCUTA'
#  'SAN JOSE DE TOLUVIEJO' 'MANAURE BALCON DEL CESAR']
# Concepto-------------------------------
# ['SERVICIOS PERSONALES ASOCIADOS A LA NOMINA'
#  'SERVICIOS PERSONALES INDIRECTOS' 'AUXILIO DE TRANSPORTE'
#  'APORTES PARA SALUD' 'APORTES PARA PENSION' 'APORTES PARA CESANTIAS'
#  'APORTES DE PREVISION SOCIAL' 'AL SECTOR PUBLICO' 'APORTES ARP'
#  'AL SECTOR PRIVADO' 'SENA' 'ICBF' 'INSTITUTOS TECNICOS'
#  'APORTES PARAFISCALES' 'CONTRIBUCIONES INHERENTES A LA NOMINA'
#  'GASTOS DE PERSONAL' 'ESAP' 'CAJAS DE COMPENSACION FAMILIAR'
#  'ADQUISICION DE BIENES' 'GASTOS FINANCIEROS' 'SEGUROS' 'SEGUROS  DE VIDA'
#  'SERVICIOS PUBLICOS' 'VIATICOS Y GASTOS DE TRANSPORTE Y DE VIAJE'
#  'ADQUISICION DE SERVICIOS' 'GASTOS GENERALES'
#  'PAGO DE BONOS PENSIONALES Y CUOTAS PARTES DE BONO PENSIONAL TIPO C Y E'
#  'A UNIVERSIDADES PUBLICAS' 'TRANSFERENCIAS CORRIENTES'
#  'TRANSFERENCIAS CORRIENTES: ESTABLECIMIENTOS PUBLICOS Y ENTIDADES DESCENTRALIZADAS-NIVEL TERRITORIAL'
#  'TRANSFERENCIA A LAS CORPORACIONES AUTONOMAS REGIONALES'
#  'PAGO DEFICIT DE FUNCIONAMIENTO'
#  'COSTOS Y GASTOS ASOCIADOS A LA OPERACION. PRODUCCION Y COMERCIALIZACION'
#  'TOTAL GASTOS DE FUNCIONAMIENTO'
#  'TRANSFERENCIA DE REGALIAS DIRECTAS POR CONCEPTO DE EXPLOTACION DE MATERIALES DE CONSTRUCCION'
#  'DOTACION DE PERSONAL' 'PRESTACIONES SOCIALES EXTRALEGALES'
#  'DE FUNCIONARIOS' 'HONORARIOS' 'BONIFICACION DE DIRECCION'
#  'INDEMNIZACION POR VACACIONES' 'PRIMAS LEGALES'
#  'HORAS EXTRAS Y DIAS FESTIVOS' 'GASTOS DE REPRESENTACION'
#  'OTROS GASTOS DE PERSONAL ASOCIADOS A LA NOMINA'
#  'PAGOS DIRECTOS DE CESANTIAS PARCIALES Y/O DEFINITIVAS'
#  'SUELDOS DE PERSONAL DE NOMINA' 'INDEMNIZACION DE PERSONAL'
#  'SERVICIOS TECNICOS' 'PERSONAL SUPERNUMERARIO' 'JORNALES'
#  'OTROS SERVICIOS PERSONALES INDIRECTOS' 'HONORARIOS DE LOS CONCEJALES'
#  'DE CONCEJALES (MUNICIPIOS DE CATEGORIA ESPECIAL. 1. 2 Y 3)'
#  'DE CONCEJALES (MUNICIPIOS DE CATEGORIA 4. 5 Y 6. A PARTIR DE LA VIGENCIA DE LA LEY 1148/07)'
#  'OTROS GASTOS DE FUNCIONAMIENTO' 'COMPRA DE EQUIPOS'
#  'MATERIALES Y SUMINISTROS' 'CAPACITACION PERSONAL ADMINISTRATIVO'
#  'OTROS GASTOS ADQUISICION DE BIENES' 'MANTENIMIENTO Y REPARACIONES'
#  'OTROS GASTOS ADQUISICION DE SERVICIOS' 'OTROS GASTOS FINANCIEROS'
#  'DIFERENCIAL CAMBIARIO' 'INTERESES DE CREDITOS DE TESORERIA'
#  'IMPRESOS Y PUBLICACIONES' 'OTROS SEGUROS' 'OTROS SEGUROS DE VIDA'
#  'POLIZA DE SEGURO DE SALUD PARA CONCEJALES (MUNICIPIOS DE CATEGORIA 4. 5 Y 6. A PARTIR DE LA VIGENCIA DE LA LEY 1148/07)'
#  'CONTRIBUCIONES. TASAS. IMPUESTOS Y MULTAS'
#  'POLIZA DE SEGURO DE SALUD PARA CONCEJALES  (MUNICIPIOS DE CATEGORIA ESPECIAL. 1. 2 Y 3)'
#  'ENERGIA'
#  'DE LOS CONCEJALES (MUNICIPIOS DE CATEGORIA 4. 5 Y 6. A PARTIR DE LA VIGENCIA DE LA LEY 1148/07)'
#  'DEL GOBERNADOR O ALCALDE' 'SEGUROS DE BIENES MUEBLES E INMUEBLES'
#  'ARRENDAMIENTOS' 'OTROS SERVICIOS PUBLICOS' 'GAS NATURAL'
#  'ACUEDUCTO. ALCANTARILLADO Y ASEO' 'TELECOMUNICACIONES'
#  'GASTOS VINCULACION DE PERSONAL ARTICULO 30 LEY 909 DE 2004'
#  'GASTOS ELECTORALES' 'OTROS GASTOS GENERALES'
#  'GASTOS DE BIENESTAR SOCIAL Y SALUD OCUPACIONAL' 'MESADAS PENSIONALES'
#  'FONDO NACIONAL DE PENSIONES TERRITORIALES FONPET'
#  'TRANSFERENCIA POR SOBRETASA PARA INVERSION EN CEDELCA (SOLO MUNICIPIOS DEL DEPTO DEL CAUCA )'
#  'AL FONDO NACIONAL DE REGALIAS'
#  'A LAS INTERVENTORIAS ADMINISTRATIVAS Y FINANCIERAS DEL DNP.'
#  'TRANSFERENCIA CUERPOS DE BOMBEROS' 'A DEPARTAMENTOS PRODUCTORES'
#  'A MUNICIPIOS O DISTRITOS PORTUARIOS' 'SENTENCIAS Y CONCILIACIONES'
#  'PAGOS A ORGANISMOS INTERNACIONALES NO CREDITICIOS'
#  'CUOTAS PARTES DE MESADA PENSIONAL'
#  'CAPITALIZACION DE PATRIMONIOS AUTONOMOS PARA PROVISION DE PENSIONES'
#  'A ESTABLECIMIENTOS PUBLICOS' 'CON SITUACION DE FONDOS'
#  'SIN SITUACION DE FONDOS' 'OTRAS TRANSFERENCIAS CORRIENTES'
#  'OTRAS TRANSFERENCIAS CORRIENTES A UNIVERSIDADES PUBLICAS'
#  'A OTRAS ENTIDADES' 'A ENTIDADES EN LIQUIDACION'
#  'A OTRAS ENTIDADES DESCENTRALIZADAS'
#  'PAGO DE PENSIONES DE DOCENTES NACIONALIZADOS'
#  'TRANSFERENCIA DE CONCURRENCIAS PARA PAGO DE PASIVOS PENSIONALES Y PRESTACIONALES'
#  'TRANSFERENCIA ARTICULO 86 LEY 30 DE 1993'
#  'SOBRETASA AMBIENTAL -CORPORACIONES AUTONOMAS REGIONALES'
#  'PARTICIPACION AMBIENTAL -CORPORACIONES AUTONOMAS REGIONALES'
#  'SOBRETASA AMBIENTAL-A AREAS METROPOLITANAS'
#  'CAUSADO CON ANTERIORIDAD AL 31 DE DIC DE 2000'
#  'CAUSADO CON POSTERIORIDAD AL 31 DE DIC DE 2000'
#  'CAUSADO CON POSTERIORIDAD A LA FIRMA DE ACUERDO DE REESTRUCTURACION DE PASIVOS-LEY 550 DE 1999'
#  'SERVICIOS PERSONALES DIRECTOS' 'TRANSFERENCIAS DE CAPITAL'
#  'CONSUMO DE INSUMOS DIRECTOS' 'CONTRIBUCIONES. IMPUESTOS Y TASAS'
#  'OTROS GASTOS GENERALES DE OPERACION. PRODUCCION Y COMERCIALIZACION'
#  'CIFRAS DE CONTROL PARA LOS GASTOS DE FUNCIONAMIENTO'
#  'BIENES COMERCIALIZADOS' 'CONSUMO DE INSUMOS INDIRECTOS'
#  'FONDO DE SUBSIDIO SOBRETASA A LA GASOLINA' 'DE DIPUTADOS'
#  'TRANSFERENCIA POR SOBRETASA ESPECIAL PARA EL DISTRITO DE CARTAGENA (VIGENTE LEY 15/ 1961)'
#  'REMUNERACION DE LOS DIPUTADOS' 'PRIMA DE NAVIDAD DIPUTADOS'
#  'TRANSFERENCIA A PROVIDENCIA Y SANTA CATALINA' 'SUBSIDIO DE ALIMENTACION'
#  'BONIFICACION POR GESTION TERRITORIAL'
#  'SUBSIDIO PARA MOVILIZACION DE PERSONEROS LEY 1551 DE 2012'
#  'DEL PERSONERO' 'TRANSFERENCIA CORRIENTE' 'ACUERDOS DE PAGO'
#  'PAGO PASIVO FONDO NACIONAL DE PRESTACIONES SOCIALES DEL MAGISTERIO -FNPSM (FOMAG)'
#  'A OTROS ESTABLECIMIENTOS PUBLICOS'
#  'TRANSFERENCIA DEPARTAMENTAL A LOS MUNICIPIOS POR SANCIONES POR IMPUESTO SOBRE VEHICULOS AUTOMORORES (20%)'
#  'A INSTITUCIONES ESTATALES U OFICIALES DE EDUCACION SUPERIOR QUE NO TENGAN EL CARACTER DE UNIVERSIDAD'
#  'TRANSFERENCIA ARTICULO 86 LEY 30 DE 1992 PARA FUNCIONAMIENTO'
#  'TRANSFERENCIA  DEPARTAMENTAL A LOS MUNICIPIOS POR IMPUESTO SOBRE VEHICULOS AUTOMOTORES (20%)'
#  'TRANSFERENCIA DEPARTAMENTAL A LOS MUNICIPIOS POR INTERESES DE MORA POR IMPUESTO SOBRE VEHICULOS AUTOMOTORES (20%)'
#  'A OTRAS ENTIDADES DIFERENTES A LAS ANTERIORES'
#  'TRANSFERENCIAS A LA POLICIA NACIONAL PARA GASTOS DE ADMINISTRACION. FUNCIONAMIENTO E INFRAESTRUCTURA']
# Unidad Ejecutora-------------------------------
# ['ADMINISTRACION CENTRAL' 'ASAMBLEA - SOLO DEPARTAMENTOS' 'CONTRALORIA'
#  'SECRETARIA DE EDUCACION' 'SECRETARIA DE SALUD'
#  'LICORES - SOLO DEPARTAMENTOS'
#  'UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS'
#  'PERSONERIA - SOLO MUNICIPIOS' 'CONCEJO - SOLO MUNICIPIOS' '']
# Código Concepto-------------------------------
# ['1.1.1' '1.1.3' '1.1.1.7' '1.1.4.1.1.1' '1.1.4.1.1.2' '1.1.4.1.1.4'
#  '1.1.4.1.1' '1.1.4.1' '1.1.4.1.1.3' '1.1.4.2.1.1' '1.1.4.2.1.2'
#  '1.1.4.2.1.4' '1.1.4.2.1' '1.1.4.2' '1.1.4.2.1.3' '1.1.4.3.1' '1.1.4.3.2'
#  '1.1.4.3.5' '1.1.4.3' '1.1.4' '1.1' '1.1.4.3.3' '1.1.4.3.4' '1.2.1'
#  '1.2.2.12' '1.2.2.3' '1.2.2.3.2' '1.2.2.6' '1.2.2.8' '1.2.2' '1.2'
#  '1.3.4' '1.3.6.4' '1.3' '1.3.6' '1.3.8' '1.4' '1.9.2' '1.9' '1' '1.9.1'
#  '1.3.18' '1.1.1.9' '1.1.1.8' '1.1.1.7.1' '1.1.3.1' '1.1.1.6' '1.1.1.5'
#  '1.1.1.4' '1.1.1.3' '1.1.1.2' '1.1.1.11' '1.1.1.10' '1.1.1.1' '1.1.2'
#  '1.1.3.4' '1.1.3.3' '1.1.3.2' '1.1.3.7' '1.1.3.6' '1.1.4.1.1.1.1'
#  '1.1.4.1.1.2.1' '1.1.4.1.1.1.4' '1.1.4.1.1.1.2' '1.1.4.1.1.3.1'
#  '1.1.4.1.1.4.1' '1.1.4.2.1.1.1' '1.1.4.2.1.1.2' '1.1.4.2.1.2.1'
#  '1.1.4.2.1.1.4' '1.1.4.2.1.3.1' '1.1.4.2.1.4.1' '1.1.4.3.1.1'
#  '1.1.4.3.2.1' '1.1.4.3.3.1' '1.1.4.3.4.1' '1.1.4.3.5.1' '1.10' '1.2.1.1'
#  '1.2.1.2' '1.2.2.1' '1.2.1.9' '1.2.2.11' '1.2.2.19' '1.2.2.12.5'
#  '1.2.2.12.2' '1.2.2.12.1' '1.2.2.2' '1.2.2.3.4' '1.2.2.3.2.4' '1.2.2.3.3'
#  '1.2.2.4' '1.2.2.3.5' '1.2.2.6.1' '1.2.2.3.2.1' '1.2.2.3.2.3'
#  '1.2.2.3.2.2' '1.2.2.3.1' '1.2.2.5' '1.2.2.8.1' '1.2.2.6.5' '1.2.2.6.4'
#  '1.2.2.6.3' '1.2.2.6.2' '1.2.2.7' '1.2.2.8.3' '1.2.2.8.2' '1.2.2.9'
#  '1.2.9' '1.2.4' '1.3.1' '1.3.12' '1.3.11' '1.3.18.3' '1.3.18.4' '1.3.15'
#  '1.3.18.1' '1.3.18.2' '1.3.19' '1.3.14' '1.3.2' '1.3.3' '1.3.6.1'
#  '1.3.4.1' '1.3.4.2' '1.3.25' '1.3.6.4.6' '1.3.6.7' '1.3.6.6' '1.3.6.5'
#  '1.3.5' '1.3.6.4.4' '1.3.6.4.1' '1.3.8.1' '1.3.8.2' '1.3.9' '1.4.1'
#  '1.4.2' '1.4.3' '1.9.1.1' '1.9.2.2' '1.8' '1.9.1.2' '1.9.2.1' '1.9.2.3'
#  '1.9.2.5' '1.9.2.8' 'VAL' '1.9.2.6' '1.9.4' '1.9.2.4' '1.9.2.7' '1.9.3'
#  '1.3.13' '1.1.4.3.2.2' '1.3.10' '1.1.4.3.4.2' '1.1.4.3.3.2' '1.1.4.3.1.2'
#  '1.1.4.2.1.3.2' '1.1.4.2.1.4.2' '1.1.4.3.5.2' '1.1.3.5' '1.1.3.8'
#  '1.1.4.1.1.1.3' '1.1.4.1.1.2.2' '1.1.4.1.1.3.2' '1.1.4.1.1.4.2'
#  '1.1.4.2.1.1.3' '1.1.4.2.1.2.2' '1.3.7' '1.1.1.25' '1.1.1.14' '1.1.1.12'
#  '1.1.5' '1.2.2.3.2.9' '1.2.2.3.2.5' '1.3.12.1' '1.3.12.2' '1.3.20'
#  '1.3.6.1.2' '1.3.24' '1.3.6.1.1' '1.3.22' '1.3.23' '1.3.6.7.10'
#  '1.3.6.7.1']

# %% [markdown]
# On the other hand, the **Guican** minicipio was incorrectly saved in the dataset and must be cleaned up.

# %%
df['Nombre DANE Municipio'] = df['Nombre DANE Municipio'].replace('GÃœICAN', 'GUICAN')

# %% [markdown]
# ### 2.3. Cleaning NaN and blank values

# %% [markdown]
# As part of the previous results, it is evident that the variable `Executing Unit` had a large number of blank data, so it will be replaced by NaN values.

# %%
df['Unidad Ejecutora'] = df['Unidad Ejecutora'].replace('', np.NaN)
df['Fuente Financiación'] = df['Fuente Financiación'].replace('', np.NaN)

# %%
df[df['Unidad Ejecutora'] == ''].count().sum()
# Out:
# 0

# %% [markdown]
# Then we will identify the columns with missing data.

# %%
df.isna().sum()
# Out:
# Código FUT                         0
# Nombre Entidad                     0
# Cód. DANE Departamento             0
# Nombre DANE Departamento           0
# Cód. DANE Municipio            93164
# Nombre DANE Municipio          93164
# Código Concepto                    0
# Concepto                           0
# Código Unidad Ejecutora        43011
# Unidad Ejecutora               42467
# Código Fuente Financiación    882087
# Fuente Financiación           839076
# Presupuesto Inicial                0
# Presupuesto Definitivo             0
# Compromisos                        1
# Obligaciones                       1
# Pagos                              5
# Año                                0
# Nivel concepto                     0
# dtype: int64

# %% [markdown]
# With a total of missing data in the dataset of:

# %%
df.isna().sum().sum()
# Out:
# 1992976

# %%
df.shape
# Out:
# (1927006, 19)

# %% [markdown]
# Since we are only interested in the columns that have a mini-municipality and based in the meeting conclusion elaborated with **Asocapitales** it is possible to eliminate the rows that do not have `Cód. DANE Municipio` or `Nombre DANE Municipio`, this is because the places given by these rows are mostly departmental data.

# %%
df.dropna(subset = ['Cód. DANE Municipio','Nombre DANE Municipio','Compromisos', 'Obligaciones', 'Pagos'], inplace = True)

# %%
df.isna().sum()
# Out:
# Código FUT                         0
# Nombre Entidad                     0
# Cód. DANE Departamento             0
# Nombre DANE Departamento           0
# Cód. DANE Municipio                0
# Nombre DANE Municipio              0
# Código Concepto                    0
# Concepto                           0
# Código Unidad Ejecutora        43011
# Unidad Ejecutora               42467
# Código Fuente Financiación    844058
# Fuente Financiación           801047
# Presupuesto Inicial                0
# Presupuesto Definitivo             0
# Compromisos                        0
# Obligaciones                       0
# Pagos                              0
# Año                                0
# Nivel concepto                     0
# dtype: int64

# %% [markdown]
# The next step is to fill in the missing values in the following columns `Código Unidad Ejecutora`,   `Código Fuente Financiación`, `Fuente Financiación`, `Unidad Ejecutora`, since these represent mostly categories we will simply add the category **otros** for fill each of the **NaN** values from these columns.

# %%
df.fillna('otros', inplace = True)

# %%
df.shape
# Out:
# (1833837, 19)

# %% [markdown]
# ### 2.4. Formating finantial Columns

# %% [markdown]
# The `Presupuesto Inicial`,`Presupuesto Definitivo`, `Compromisos`, `Obligaciones`, `Pagos` variables belong to all the columns that refer to financial values, i.e. the amounts of money that each municipality reported for these subjects.

# %%
financial_columns = ['Presupuesto Inicial','Presupuesto Definitivo', 'Compromisos', 'Obligaciones', 'Pagos']

# %%
df[financial_columns]
# Out:
#         Presupuesto Inicial Presupuesto Definitivo   Compromisos  \
# 4131                 10.772                 14.541        14.382
# 4132                 28.410                 28.576        25.865
# 4133                 12.135                 12.134        11.385
# 4134                 40.650                 40.650        33.327
# 4135                215.659                209.547       196.295
# ...                     ...                    ...           ...
# 1927001        1004894870.0           1004894870.0  1004894870.0
# 1927002        1004894870.0           1004894870.0  1004894870.0
# 1927003        1004894870.0           1004894870.0  1004894870.0
# 1927004        1004894870.0           1004894870.0  1004894870.0
# 1927005        1004894870.0           1004894870.0  1004894870.0
#
#          Obligaciones         Pagos
# 4131           14.382        14.382
# 4132           25.865        25.865
# 4133           11.385        11.385
# 4134           33.327        33.327
# 4135          196.295       196.295
# ...               ...           ...
# 1927001  1004894870.0  1004894870.0
# 1927002  1004894870.0  1004894870.0
# 1927003  1004894870.0  1004894870.0
# 1927004  1004894870.0  1004894870.0
# 1927005  1004894870.0  1004894870.0
#
# [1833837 rows x 5 columns]

# %% [markdown]
# These variables are in string format, so it is first necessary to remove the period from each string and then transform it to a numerical data.

# %%
df[financial_columns] = df[financial_columns].replace(r'\.','', regex=True).astype('int64')

# %% [markdown]
# On the other hand, the financial records prior to 2017 are in thousands, so it is necessary to add 3 zeros to these data to adjust them to the later years, which are in pesos.

# %%
df.loc[df['Año'] < 2017, financial_columns] = df[financial_columns]*1000

# %%
df[financial_columns]
# Out:
#          Presupuesto Inicial  Presupuesto Definitivo  Compromisos  \
# 4131                10772000                14541000     14382000
# 4132                28410000                28576000     25865000
# 4133                12135000                12134000     11385000
# 4134                40650000                40650000     33327000
# 4135               215659000               209547000    196295000
# ...                      ...                     ...          ...
# 1927001           1004894870              1004894870   1004894870
# 1927002           1004894870              1004894870   1004894870
# 1927003           1004894870              1004894870   1004894870
# 1927004           1004894870              1004894870   1004894870
# 1927005           1004894870              1004894870   1004894870
#
#          Obligaciones       Pagos
# 4131         14382000    14382000
# 4132         25865000    25865000
# 4133         11385000    11385000
# 4134         33327000    33327000
# 4135        196295000   196295000
# ...               ...         ...
# 1927001    1004894870  1004894870
# 1927002    1004894870  1004894870
# 1927003    1004894870  1004894870
# 1927004    1004894870  1004894870
# 1927005    1004894870  1004894870
#
# [1833837 rows x 5 columns]

# %% [markdown]
# ## 3. Data merging

# %% [markdown]
# In order to join the operational expenses dataframe with other dataframes, a `Key` column is generated that links the municipality and the year.

# %% [markdown]
# ### 3.1. Key generation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1833837 entries, 4131 to 1927005
# Data columns (total 19 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Código FUT                  int64
#  1   Nombre Entidad              object
#  2   Cód. DANE Departamento      int64
#  3   Nombre DANE Departamento    object
#  4   Cód. DANE Municipio         float64
#  5   Nombre DANE Municipio       object
#  6   Código Concepto             object
#  7   Concepto                    object
#  8   Código Unidad Ejecutora     object
#  9   Unidad Ejecutora            object
#  10  Código Fuente Financiación  object
#  11  Fuente Financiación         object
#  12  Presupuesto Inicial         int64
#  13  Presupuesto Definitivo      int64
#  14  Compromisos                 int64
#  15  Obligaciones                int64
#  16  Pagos                       int64
#  17  Año                         int64
#  18  Nivel concepto              int64
# dtypes: float64(1), int64(9), object(9)
# memory usage: 344.3+ MB

# %%
df['Cód. DANE Municipio'] = df['Cód. DANE Municipio'].astype('int64')

# %%
df['key'] = df['Cód. DANE Municipio'].astype('string').str.cat(df['Año'].astype('string'), sep = "_")

# %% [markdown]
# ### 3.2. Merging the dataframes

# %% [markdown]
# The first thing that is done is the call to the Dataframe of categories that relates the category in which each municipality was classified by year.

# %%
categories = pd.read_csv('categories.csv', sep = ",", encoding = 'utf-8')
categories.drop(columns = ['departamento', 'MUNICIPIO', 'cod_municipio', 'año'], inplace = True)
categories
# Out:
#       categoria         key
# 0           ESP   5001_2012
# 1           ESP   8001_2012
# 2           ESP  11001_2012
# 3           ESP  13001_2012
# 4           ESP  68001_2012
# ...         ...         ...
# 12095         6  97666_2022
# 12096         6  99001_2022
# 12097         6  99524_2022
# 12098         6  99624_2022
# 12099         4  99773_2022
#
# [12100 rows x 2 columns]

# %%
df2 = pd.merge(df, categories, on = 'key')
df2
# Out:
#          Código FUT Nombre Entidad  Cód. DANE Departamento  \
# 0         219215092      BETEITIVA                      15
# 1         219215092      BETEITIVA                      15
# 2         219215092      BETEITIVA                      15
# 3         219215092      BETEITIVA                      15
# 4         219215092      BETEITIVA                      15
# ...             ...            ...                     ...
# 1832674   219925899      ZIPAQUIRA                      25
# 1832675   219925899      ZIPAQUIRA                      25
# 1832676   219925899      ZIPAQUIRA                      25
# 1832677   219925899      ZIPAQUIRA                      25
# 1832678   219925899      ZIPAQUIRA                      25
#
#         Nombre DANE Departamento  Cód. DANE Municipio Nombre DANE Municipio  \
# 0                         BOYACA                15092             BETEITIVA
# 1                         BOYACA                15092             BETEITIVA
# 2                         BOYACA                15092             BETEITIVA
# 3                         BOYACA                15092             BETEITIVA
# 4                         BOYACA                15092             BETEITIVA
# ...                          ...                  ...                   ...
# 1832674             CUNDINAMARCA                25899             ZIPAQUIRA
# 1832675             CUNDINAMARCA                25899             ZIPAQUIRA
# 1832676             CUNDINAMARCA                25899             ZIPAQUIRA
# 1832677             CUNDINAMARCA                25899             ZIPAQUIRA
# 1832678             CUNDINAMARCA                25899             ZIPAQUIRA
#
#         Código Concepto                                           Concepto  \
# 0                 1.1.1         SERVICIOS PERSONALES ASOCIADOS A LA NOMINA
# 1           1.1.4.2.1.2                               APORTES PARA PENSION
# 2           1.1.4.2.1.1                                 APORTES PARA SALUD
# 3                 1.1.3                    SERVICIOS PERSONALES INDIRECTOS
# 4                     1                     TOTAL GASTOS DE FUNCIONAMIENTO
# ...                 ...                                                ...
# 1832674             VAL  CIFRAS DE CONTROL PARA LOS GASTOS DE FUNCIONAM...
# 1832675               1                     TOTAL GASTOS DE FUNCIONAMIENTO
# 1832676             1.2                                   GASTOS GENERALES
# 1832677           1.2.9                             OTROS GASTOS GENERALES
# 1832678           1.2.9                             OTROS GASTOS GENERALES
#
#         Código Unidad Ejecutora  \
# 0                           8.0
# 1                           8.0
# 2                           8.0
# 3                           8.0
# 4                           8.0
# ...                         ...
# 1832674                   otros
# 1832675                   otros
# 1832676                   otros
# 1832677                   otros
# 1832678                   otros
#
#                                        Unidad Ejecutora  ...  \
# 0        UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 1        UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 2        UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 3        UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 4        UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# ...                                                 ...  ...
# 1832674                                           otros  ...
# 1832675                                           otros  ...
# 1832676                                           otros  ...
# 1832677                                           otros  ...
# 1832678                                           otros  ...
#
#                                        Fuente Financiación  \
# 0                                                    otros
# 1                                                    otros
# 2                                                    otros
# 3                                                    otros
# 4                                                    otros
# ...                                                    ...
# 1832674  MUNICIPIOS  - INGRESOS CORRIENTES DE LIBRE DES...
# 1832675
# 1832676
# 1832677
# 1832678  MUNICIPIOS  - INGRESOS CORRIENTES DE LIBRE DES...
#
#         Presupuesto Inicial  Presupuesto Definitivo  Compromisos  \
# 0                  10772000                14541000     14382000
# 1                   1571000                 2016000      2016000
# 2                   1006000                 1325000      1325000
# 3                   7507000                13445000     13445000
# 4                  33700000                51700000     51110000
# ...                     ...                     ...          ...
# 1832674          1004894870              1004894870   1004894870
# 1832675          1004894870              1004894870   1004894870
# 1832676          1004894870              1004894870   1004894870
# 1832677          1004894870              1004894870   1004894870
# 1832678          1004894870              1004894870   1004894870
#
#          Obligaciones       Pagos   Año  Nivel concepto         key categoria
# 0            14382000    14382000  2012               3  15092_2012         6
# 1             2016000     2016000  2012               6  15092_2012         6
# 2             1325000     1325000  2012               6  15092_2012         6
# 3            13445000    13445000  2012               3  15092_2012         6
# 4            51110000    51110000  2012               1  15092_2012         6
# ...               ...         ...   ...             ...         ...       ...
# 1832674    1004894870  1004894870  2021               3  25899_2021         2
# 1832675    1004894870  1004894870  2021               1  25899_2021         2
# 1832676    1004894870  1004894870  2021               2  25899_2021         2
# 1832677    1004894870  1004894870  2021               3  25899_2021         2
# 1832678    1004894870  1004894870  2021               3  25899_2021         2
#
# [1832679 rows x 21 columns]

# %% [markdown]
# ### 3.2 `Nivel categoria` dataset splitting.

# %% [markdown]
# Since the `Nivel de categoria`, i.e. the `codigo de concepto`, at the lowest levels 1,2,3..., aggregates the values of the other levels, it is necessary to split the dataset into multiple even smaller datasets that allow us to evaluate in a simpler way the financial ranges evaluated for each level.

# %%
nivel_1 = df2[df2['Nivel concepto'] == 1]
nivel_2 = df2[df2['Nivel concepto'] == 2]
nivel_3 = df2[df2['Nivel concepto'] == 3]
nivel_4 = df2[df2['Nivel concepto'] == 4]
nivel_5 = df2[df2['Nivel concepto'] == 5]
nivel_6 = df2[df2['Nivel concepto'] == 6]
nivel_7 = df2[df2['Nivel concepto'] == 7]

# %% [markdown]
# ### 4. Oulier detection

# %% [markdown]
# Due to multiple typing errors when filling in the values corresponding to the financial variables in the expenditure and operations form, it is necessary to detect the outliers in order to rewrite them in such a way that they are adjusted to the category of the municipality, the year and the type of concept. In addition to this and as seen previously, the  `Nivel categoria` column was generated to identify the length of the code of the concept to which each expense refers.

# %%
df['Nivel concepto'].unique()
# Out:
# array([3, 4, 6, 5, 2, 1, 7], dtype=int64)

# %% [markdown]
# With this we identified that there are 7 levels

# %% [markdown]
# ### 4.1. Particularities in the data by `Nivel categoria`

# %% [markdown]
# During the EDA, many municipalities of small size and low income were identified as outliers, including examples such as the municipality of **MAICAO** `categoria` $4$, which had expenditures similar to municipalities classified as `categoria` **ESP** like **BOGOTA** or **MEDELLIN**.

# %%
nivel_7[(nivel_7['Nombre DANE Municipio'] == 'MAICAO')]
# Out:
#          Código FUT Nombre Entidad  Cód. DANE Departamento  \
# 147532    213044430         MAICAO                      44
# 147533    213044430         MAICAO                      44
# 147534    213044430         MAICAO                      44
# 147535    213044430         MAICAO                      44
# 378696    213044430         MAICAO                      44
# ...             ...            ...                     ...
# 1811022   213044430         MAICAO                      44
# 1811024   213044430         MAICAO                      44
# 1811025   213044430         MAICAO                      44
# 1811027   213044430         MAICAO                      44
# 1811028   213044430         MAICAO                      44
#
#         Nombre DANE Departamento  Cód. DANE Municipio Nombre DANE Municipio  \
# 147532                LA GUAJIRA                44430                MAICAO
# 147533                LA GUAJIRA                44430                MAICAO
# 147534                LA GUAJIRA                44430                MAICAO
# 147535                LA GUAJIRA                44430                MAICAO
# 378696                LA GUAJIRA                44430                MAICAO
# ...                          ...                  ...                   ...
# 1811022               LA GUAJIRA                44430                MAICAO
# 1811024               LA GUAJIRA                44430                MAICAO
# 1811025               LA GUAJIRA                44430                MAICAO
# 1811027               LA GUAJIRA                44430                MAICAO
# 1811028               LA GUAJIRA                44430                MAICAO
#
#         Código Concepto         Concepto Código Unidad Ejecutora  \
# 147532    1.1.4.1.1.3.1  DE FUNCIONARIOS                     1.0
# 147533    1.1.4.2.1.1.1  DE FUNCIONARIOS                     1.0
# 147534    1.1.4.2.1.2.1  DE FUNCIONARIOS                     1.0
# 147535    1.1.4.2.1.4.1  DE FUNCIONARIOS                     1.0
# 378696    1.1.4.1.1.1.1  DE FUNCIONARIOS                     1.0
# ...                 ...              ...                     ...
# 1811022   1.1.4.2.1.2.1  DE FUNCIONARIOS                   otros
# 1811024   1.1.4.2.1.3.1  DE FUNCIONARIOS                   otros
# 1811025   1.1.4.2.1.3.1  DE FUNCIONARIOS                   otros
# 1811027   1.1.4.2.1.4.1  DE FUNCIONARIOS                   otros
# 1811028   1.1.4.2.1.4.1  DE FUNCIONARIOS                   otros
#
#                Unidad Ejecutora  ...  \
# 147532   ADMINISTRACION CENTRAL  ...
# 147533   ADMINISTRACION CENTRAL  ...
# 147534   ADMINISTRACION CENTRAL  ...
# 147535   ADMINISTRACION CENTRAL  ...
# 378696   ADMINISTRACION CENTRAL  ...
# ...                         ...  ...
# 1811022                   otros  ...
# 1811024                   otros  ...
# 1811025                   otros  ...
# 1811027                   otros  ...
# 1811028                   otros  ...
#
#                                        Fuente Financiación  \
# 147532   MUNICIPIOS  - INGRESOS CORRIENTES DE LIBRE DES...
# 147533   MUNICIPIOS  - INGRESOS CORRIENTES DE LIBRE DES...
# 147534   MUNICIPIOS  - INGRESOS CORRIENTES DE LIBRE DES...
# 147535   MUNICIPIOS  - INGRESOS CORRIENTES DE LIBRE DES...
# 378696   MUNICIPIOS  - INGRESOS CORRIENTES DE LIBRE DES...
# ...                                                    ...
# 1811022  SGP EDUCACIÓN PRESTACIÓN DEL SERVICIO DOCE DOC...
# 1811024
# 1811025  SGP EDUCACIÓN PRESTACIÓN DEL SERVICIO DOCE DOC...
# 1811027
# 1811028  SGP EDUCACIÓN PRESTACIÓN DEL SERVICIO DOCE DOC...
#
#         Presupuesto Inicial  Presupuesto Definitivo  Compromisos  \
# 147532              6833000                 7280000      7280000
# 147533            111273000               120281000    120281000
# 147534            157091000               169932000    169932000
# 147535            109091000               149165000    149106000
# 378696            148787000               123878000    123675000
# ...                     ...                     ...          ...
# 1811022           129841800               129841800    123448000
# 1811024             5403996                 5403996      5173000
# 1811025             5403996                 5403996      5173000
# 1811027           116753640               116753640    108163170
# 1811028           116753640               116753640    108163170
#
#          Obligaciones      Pagos   Año  Nivel concepto         key categoria
# 147532        7280000    7280000  2012               7  44430_2012         4
# 147533      120281000  120281000  2012               7  44430_2012         4
# 147534      169932000  169932000  2012               7  44430_2012         4
# 147535      149106000  149106000  2012               7  44430_2012         4
# 378696      123675000  123675000  2013               7  44430_2013         4
# ...               ...        ...   ...             ...         ...       ...
# 1811022     123448000  123448000  2021               7  44430_2021         4
# 1811024       5173000    5173000  2021               7  44430_2021         4
# 1811025       5173000    5173000  2021               7  44430_2021         4
# 1811027     108163170  108163170  2021               7  44430_2021         4
# 1811028     108163170  108163170  2021               7  44430_2021         4
#
# [77 rows x 21 columns]

# %% [markdown]
# ### 4.2 Defining outlier cleaning function.

# %% [markdown]
# As previously mentioned, since the outliers are mostly typing errors, it is necessary to adjust these data to match other data typed for the same `Cód. DANE Municipio`, for the same `Código Concepto` and for the same `Código Unidad Ejecutora`. In such a way that the detection of outliers is focused on a specific amount, so that this detection is not affected by outliers generated by different concepts, municipalities or executing units.

# %% [markdown]
# To this end, the following function is generated, a series of for cycles in order to evaluate all the rows of the dataset, in this way we have that:
#
# 1. The data is filtered by `Cód. DANE Municipio`, until all the municipalities are evaluated.
# 2. Filter the previous result by `codigo concepto`, until all the concepts of that municipality are evaluated.
# 3. The previous result is filtered by `unidad ejecutora`, until all the executing units of that concept code are evaluated.
#
# For the identification of the outlier, the maximum given by the interquartile range is calculated.
#
# $$maximum = Q3 + IQR * 1.5$$.
#
# This means that all values higher than this value will be identified as outliers, however, since some outliers can be very close to the maximum and since the most common typing error involves typing more than one zero or one zero on the real value, only those values exceeding up to 9 times the value of the maximum will be rewritten. This is done by calculating how many times the value exceeds the maximum and dividing this value using a power of 10.
#
# In this way the rewriting of the values is not affected by other outliers and no individuals are lost.

# %%
def clean_by_municipality(df):
    df = df.copy()
    df_limpio = pd.DataFrame()
    for column in list(df.columns):
        df_limpio[column] = []
    
    cods_municipios = list(df['Cód. DANE Municipio'].unique())
    for cod_municipio in cods_municipios:
        df_municipios = df[df['Cód. DANE Municipio'] == cod_municipio].copy()    
        cods_conceptos = list(df_municipios['Código Concepto'].unique())

        for cod_concepto in cods_conceptos:
            df_conceptos = df_municipios[df_municipios['Código Concepto'] == cod_concepto].copy() 
            cods_ejecutoras = list(df_conceptos['Código Unidad Ejecutora'].unique())
            
            for cod_ejecutora in cods_ejecutoras:
                df_ejecutoras = df_conceptos[df_conceptos['Código Unidad Ejecutora'] == cod_ejecutora].copy()
                
                for finantial_column in financial_columns:
                    data = df_ejecutoras[finantial_column]
                    q_25, q_75 = data.quantile([0.25,0.75])
                    IQR = q_75 - q_25
                    maximum = q_75 + IQR * 1.5
                    for val in data:
                        if val > maximum * 9:
                            valor = int(val/(data.median()+1))
                            potencia = len(str(valor))-1
                            divisor = 10 ** potencia
                            df_ejecutoras[finantial_column] = df_ejecutoras[finantial_column].replace(val, val/divisor)
                
                df_limpio = pd.concat([df_limpio, df_ejecutoras], axis = 0)
    
    return df_limpio

# %% [markdown]
# ### 4.3 `Clean_by_municipality` filter result

# %% [markdown]
# As can be seen for the reference municipality **MAICAO**, the number of outflows for level one completely disappears.

# %%
nivel_1_limpio = clean_by_municipality(nivel_1)
nivel_1_limpio.to_csv('Gatos_totales_nivel_1_limpio.csv')

# %% [markdown]
# Outliers previous filter application.

# %%
plt.figure(figsize=(16, 10))
nivel_1[(nivel_1['Nombre DANE Municipio'] == 'MAICAO')].boxplot(column=financial_columns)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers posterior filter application.

# %%
plt.figure(figsize=(16, 10))
nivel_1_limpio[(nivel_1_limpio['Nombre DANE Municipio'] == 'MAICAO')].boxplot(column=financial_columns)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This process is then repeated for levels 2 and 3 according to the concept code.

# %%
nivel_1.to_csv('Gatos_totales_nivel_1.csv')
nivel_2.to_csv('Gatos_totales_nivel_2.csv')
nivel_3.to_csv('Gatos_totales_nivel_3.csv')

# %% [markdown]
# nivel_2_limpio = limpiar_outliers(nivel_2)
# nivel_2_limpio.to_csv('Gatos_totales_nivel_2_limpio.csv')

# %% [markdown]
# nivel_3_limpio = limpiar_outliers(nivel_3)
# nivel_3_limpio.to_csv('Gatos_totales_nivel_3_limpio.csv')

# %% [markdown]
# ## 5. Clean ouliers by category.

# %% [markdown]
# Although the results of the first filter are very effective in evaluating the outliers within each `Cód. DANE Municipio`, `Código Concepto` and `Código Unidad Ejecutora`. It is necessary to evaluate the outliers within each category to which each municipality belongs, since it is not logical that a category 4 municipality presents higher expenditures than the municipalities of the special categories or of the categories of a higher level.
#
# Para ello y bajo el presunto que las categorias de mayor nivel **ESP**, **1**, **2**, llevan un mejor control de los datos solo se evaluaran los ouliers dentro de las categorias **3**, **4**, **5** y **6**.
#
# To this end, the following function is generated, a series of for cycles in order to evaluate all the rows of the dataset, in this way we have that:
#
# 1. The data is filtered by `categoria`, until all the categories are evaluated.
# 2. Filter the previous result by `Código Unidad Ejecutora`, until all the **unidades ejecutoras** of that categories are evaluated.
# 3. The previous result is filtered by `Año`, until all the  years of that Unidad Ejecutora are evaluated.
#
# For the identification of the outlier, the maximum given by the interquartile range is calculated.
#
# $$maximum = Q3 + IQR * 1.5$$.
#
# In this case, as with the previous filter, the maximums given by the IQR will be evaluated, with the difference that the value identified as outlier will be divided by 10 until its value is close to but not lower than the median. Without losing individuals values or that the rewrite values are affected by the outliers.

# %%
def clean_outliers_by_category(df):
    df_limpio = pd.DataFrame()
    df_otras = df[(df['categoria'] == 'ESP') | (df['categoria'] == '1') | (df['categoria'] == '2')]
    
    for column in list(df.columns):
        df_limpio[column] = []
    
    categorias = ['3','4','5','6']
    
    for categoria in categorias:
        df_categoria = df[df['categoria'] == categoria].copy()
        cods_ejecutora= list(df_categoria['Código Unidad Ejecutora'].unique())
        
        for cod_ejecutora in cods_ejecutora:
            df_ejecutora = df_categoria[df_categoria['Código Unidad Ejecutora'] == cod_ejecutora].copy()    
            años = list(df_ejecutora['Año'].unique())
            for año in años:
                df_años = df_ejecutora[df_ejecutora['Año'] == año].copy() 

                for finantial_column in financial_columns:
                    data = df_años[finantial_column]
                    q_25, q_75 = data.quantile([0.25,0.75])
                    IQR = q_75 - q_25
                    maximum = q_75 + IQR * 1.5
                    median = data.median()
                    #print(finantial_column+ '---------------------')
                    for val in data:
                        #print('Val '+str(val))
                        if val > maximum:
                            new_val = val
                            while True:
                                #print('median '+str(median))
                                new_val /= 10
                                #print('new_val '+str(new_val))
                                if median >= new_val:
                                    break
                            df_años[finantial_column] = df_años[finantial_column].replace(val, new_val)

                df_limpio = pd.concat([df_limpio, df_años], axis = 0)
    
    df_limpio = pd.concat([df_otras, df_limpio], axis = 0)
    return df_limpio

# %% [markdown]
# ## 5.1 Verification `Clean_ouliers_by_category` function.

# %% [markdown]
# The first thing that is verified is that when the filter is applied to the concept level 1 data, the data that appear within the first 60 data from highest to lowest are municipalities of category **ESP** or level **1**, which is what financially better adjusts to the real behavior of these municipalities. There is no evidence that any municipality from other categories is among the first 60 individuals.

# %%
nivel_1_limpio_categorias = clean_outliers_by_category(nivel_1_limpio)

# %%
nivel_1_limpio_categorias.sort_values(by = 'Presupuesto Inicial', ascending = False)[0:60]
# Out:
#           Código FUT                                     Nombre Entidad  \
# 1591537  210111001.0                                        BOGOTA D.C.
# 1411147  210111001.0                                        BOGOTA D.C.
# 980032   210111001.0                                        BOGOTA D.C.
# 785999   210111001.0                                        BOGOTA D.C.
# 1194027  210111001.0                                        BOGOTA D.C.
# 1791120  210111001.0                                       BOGOTA. D.C.
# 580210   210111001.0                                        BOGOTA D.C.
# 412848   210111001.0                                        BOGOTA D.C.
# 215835   210111001.0                                        BOGOTA D.C.
# 3529     210111001.0                                        BOGOTA D.C.
# 1800069  210176001.0                                               CALI
# 1630573  210176001.0                                   SANTIAGO DE CALI
# 1630926  210105001.0                                           MEDELLIN
# 1424576  210105001.0                                           MEDELLIN
# 1427491  210176001.0                                   SANTIAGO DE CALI
# 1221548  210105001.0                                           MEDELLIN
# 1007207  210105001.0                                           MEDELLIN
# 1263047  210176001.0                                   SANTIAGO DE CALI
# 793492   210105001.0                                           MEDELLIN
# 445717   210105001.0                                           MEDELLIN
# 634090   210105001.0                                           MEDELLIN
# 273839   210176001.0                                   SANTIAGO DE CALI
# 1034439  210176001.0                                   SANTIAGO DE CALI
# 231961   210105001.0                                           MEDELLIN
# 624827   210176001.0                                   SANTIAGO DE CALI
# 66206    210105001.0                                           MEDELLIN
# 1439876  210108001.0  BARRANQUILLA. DISTRITO ESPECIAL. INDUSTRIAL Y ...
# 470808   210176001.0                                   SANTIAGO DE CALI
# 848453   210176001.0                                   SANTIAGO DE CALI
# 65916    210176001.0                                   SANTIAGO DE CALI
# 1632991  210108001.0  BARRANQUILLA. DISTRITO ESPECIAL. INDUSTRIAL Y ...
# 1634656  210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 1259481  210108001.0  BARRANQUILLA. DISTRITO ESPECIAL. INDUSTRIAL Y ...
# 1591439  210111001.0                                        BOGOTA D.C.
# 1432168  210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 1006203  210108001.0  BARRANQUILLA. DISTRITO ESPECIAL. INDUSTRIAL Y ...
# 1221827  210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 1193932  210111001.0                                        BOGOTA D.C.
# 1411140  210111001.0                                        BOGOTA D.C.
# 979924   210111001.0                                        BOGOTA D.C.
# 1000868  210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 793780   210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 1791803  210111001.0                                       BOGOTA. D.C.
# 813849   210108001.0  BARRANQUILLA. DISTRITO ESPECIAL. INDUSTRIAL Y ...
# 665956   210108001.0  BARRANQUILLA. DISTRITO ESPECIAL. INDUSTRIAL Y ...
# 445397   210108001.0  BARRANQUILLA. DISTRITO ESPECIAL. INDUSTRIAL Y ...
# 785886   210111001.0                                        BOGOTA D.C.
# 259807   210108001.0  BARRANQUILLA. DISTRITO ESPECIAL. INDUSTRIAL Y ...
# 580094   210111001.0                                        BOGOTA D.C.
# 625436   210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 412698   210111001.0                                        BOGOTA D.C.
# 445048   210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 215710   210111001.0                                        BOGOTA D.C.
# 1591459  210111001.0                                        BOGOTA D.C.
# 1791410  210111001.0                                       BOGOTA. D.C.
# 1791512  210111001.0                                       BOGOTA. D.C.
# 66923    210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 232311   210113001.0  CARTAGENA DE INDIAS. DISTRITO TURISTICO Y CULT...
# 1591407  210111001.0                                        BOGOTA D.C.
# 1629774  210166001.0                                            PEREIRA
#
#          Cód. DANE Departamento Nombre DANE Departamento  Cód. DANE Municipio  \
# 1591537                    11.0             BOGOTA. D.C.              11001.0
# 1411147                    11.0             BOGOTA. D.C.              11001.0
# 980032                     11.0             BOGOTA. D.C.              11001.0
# 785999                     11.0             BOGOTA. D.C.              11001.0
# 1194027                    11.0             BOGOTA. D.C.              11001.0
# 1791120                    11.0             BOGOTA. D.C.              11001.0
# 580210                     11.0             BOGOTA. D.C.              11001.0
# 412848                     11.0             BOGOTA. D.C.              11001.0
# 215835                     11.0             BOGOTA. D.C.              11001.0
# 3529                       11.0             BOGOTA. D.C.              11001.0
# 1800069                    76.0          VALLE DEL CAUCA              76001.0
# 1630573                    76.0          VALLE DEL CAUCA              76001.0
# 1630926                     5.0                ANTIOQUIA               5001.0
# 1424576                     5.0                ANTIOQUIA               5001.0
# 1427491                    76.0          VALLE DEL CAUCA              76001.0
# 1221548                     5.0                ANTIOQUIA               5001.0
# 1007207                     5.0                ANTIOQUIA               5001.0
# 1263047                    76.0          VALLE DEL CAUCA              76001.0
# 793492                      5.0                ANTIOQUIA               5001.0
# 445717                      5.0                ANTIOQUIA               5001.0
# 634090                      5.0                ANTIOQUIA               5001.0
# 273839                     76.0          VALLE DEL CAUCA              76001.0
# 1034439                    76.0          VALLE DEL CAUCA              76001.0
# 231961                      5.0                ANTIOQUIA               5001.0
# 624827                     76.0          VALLE DEL CAUCA              76001.0
# 66206                       5.0                ANTIOQUIA               5001.0
# 1439876                     8.0                ATLANTICO               8001.0
# 470808                     76.0          VALLE DEL CAUCA              76001.0
# 848453                     76.0          VALLE DEL CAUCA              76001.0
# 65916                      76.0          VALLE DEL CAUCA              76001.0
# 1632991                     8.0                ATLANTICO               8001.0
# 1634656                    13.0                  BOLIVAR              13001.0
# 1259481                     8.0                ATLANTICO               8001.0
# 1591439                    11.0             BOGOTA. D.C.              11001.0
# 1432168                    13.0                  BOLIVAR              13001.0
# 1006203                     8.0                ATLANTICO               8001.0
# 1221827                    13.0                  BOLIVAR              13001.0
# 1193932                    11.0             BOGOTA. D.C.              11001.0
# 1411140                    11.0             BOGOTA. D.C.              11001.0
# 979924                     11.0             BOGOTA. D.C.              11001.0
# 1000868                    13.0                  BOLIVAR              13001.0
# 793780                     13.0                  BOLIVAR              13001.0
# 1791803                    11.0             BOGOTA. D.C.              11001.0
# 813849                      8.0                ATLANTICO               8001.0
# 665956                      8.0                ATLANTICO               8001.0
# 445397                      8.0                ATLANTICO               8001.0
# 785886                     11.0             BOGOTA. D.C.              11001.0
# 259807                      8.0                ATLANTICO               8001.0
# 580094                     11.0             BOGOTA. D.C.              11001.0
# 625436                     13.0                  BOLIVAR              13001.0
# 412698                     11.0             BOGOTA. D.C.              11001.0
# 445048                     13.0                  BOLIVAR              13001.0
# 215710                     11.0             BOGOTA. D.C.              11001.0
# 1591459                    11.0             BOGOTA. D.C.              11001.0
# 1791410                    11.0             BOGOTA. D.C.              11001.0
# 1791512                    11.0             BOGOTA. D.C.              11001.0
# 66923                      13.0                  BOLIVAR              13001.0
# 232311                     13.0                  BOLIVAR              13001.0
# 1591407                    11.0             BOGOTA. D.C.              11001.0
# 1629774                    66.0                RISARALDA              66001.0
#
#         Nombre DANE Municipio Código Concepto                        Concepto  \
# 1591537          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1411147          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 980032           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 785999           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1194027          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1791120          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 580210           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 412848           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 215835           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 3529             BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1800069                  CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1630573                  CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1630926              MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1424576              MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1427491                  CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1221548              MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1007207              MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1263047                  CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 793492               MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 445717               MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 634090               MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 273839                   CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1034439                  CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 231961               MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 624827                   CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 66206                MEDELLIN               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1439876          BARRANQUILLA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 470808                   CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 848453                   CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 65916                    CALI               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1632991          BARRANQUILLA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1634656             CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1259481          BARRANQUILLA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1591439          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1432168             CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1006203          BARRANQUILLA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1221827             CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1193932          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1411140          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 979924           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1000868             CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 793780              CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1791803          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 813849           BARRANQUILLA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 665956           BARRANQUILLA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 445397           BARRANQUILLA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 785886           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 259807           BARRANQUILLA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 580094           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 625436              CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 412698           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 445048              CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 215710           BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1591459          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1791410          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1791512          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 66923               CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 232311              CARTAGENA               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1591407          BOGOTA. D.C.               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1629774               PEREIRA               1  TOTAL GASTOS DE FUNCIONAMIENTO
#
#         Código Unidad Ejecutora  \
# 1591537                     1.0
# 1411147                     1.0
# 980032                      1.0
# 785999                      1.0
# 1194027                     1.0
# 1791120                   otros
# 580210                      1.0
# 412848                      1.0
# 215835                      1.0
# 3529                        1.0
# 1800069                   otros
# 1630573                     1.0
# 1630926                     1.0
# 1424576                     1.0
# 1427491                     1.0
# 1221548                     1.0
# 1007207                     1.0
# 1263047                     1.0
# 793492                      1.0
# 445717                      1.0
# 634090                      1.0
# 273839                      1.0
# 1034439                     1.0
# 231961                      1.0
# 624827                      1.0
# 66206                       1.0
# 1439876                     1.0
# 470808                      1.0
# 848453                      1.0
# 65916                       1.0
# 1632991                     1.0
# 1634656                     1.0
# 1259481                     1.0
# 1591439                     8.0
# 1432168                     1.0
# 1006203                     1.0
# 1221827                     1.0
# 1193932                     8.0
# 1411140                     8.0
# 979924                      8.0
# 1000868                     1.0
# 793780                      1.0
# 1791803                   otros
# 813849                      1.0
# 665956                      1.0
# 445397                      1.0
# 785886                      8.0
# 259807                      1.0
# 580094                      8.0
# 625436                      1.0
# 412698                      8.0
# 445048                      1.0
# 215710                      8.0
# 1591459                     4.0
# 1791410                   otros
# 1791512                   otros
# 66923                       1.0
# 232311                      1.0
# 1591407                     5.0
# 1629774                     1.0
#
#                                        Unidad Ejecutora  ...  \
# 1591537                          ADMINISTRACION CENTRAL  ...
# 1411147                          ADMINISTRACION CENTRAL  ...
# 980032                           ADMINISTRACION CENTRAL  ...
# 785999                           ADMINISTRACION CENTRAL  ...
# 1194027                          ADMINISTRACION CENTRAL  ...
# 1791120                                           otros  ...
# 580210                           ADMINISTRACION CENTRAL  ...
# 412848                           ADMINISTRACION CENTRAL  ...
# 215835                           ADMINISTRACION CENTRAL  ...
# 3529                             ADMINISTRACION CENTRAL  ...
# 1800069                                           otros  ...
# 1630573                          ADMINISTRACION CENTRAL  ...
# 1630926                          ADMINISTRACION CENTRAL  ...
# 1424576                          ADMINISTRACION CENTRAL  ...
# 1427491                          ADMINISTRACION CENTRAL  ...
# 1221548                          ADMINISTRACION CENTRAL  ...
# 1007207                          ADMINISTRACION CENTRAL  ...
# 1263047                          ADMINISTRACION CENTRAL  ...
# 793492                           ADMINISTRACION CENTRAL  ...
# 445717                           ADMINISTRACION CENTRAL  ...
# 634090                           ADMINISTRACION CENTRAL  ...
# 273839                           ADMINISTRACION CENTRAL  ...
# 1034439                          ADMINISTRACION CENTRAL  ...
# 231961                           ADMINISTRACION CENTRAL  ...
# 624827                           ADMINISTRACION CENTRAL  ...
# 66206                            ADMINISTRACION CENTRAL  ...
# 1439876                          ADMINISTRACION CENTRAL  ...
# 470808                           ADMINISTRACION CENTRAL  ...
# 848453                           ADMINISTRACION CENTRAL  ...
# 65916                            ADMINISTRACION CENTRAL  ...
# 1632991                          ADMINISTRACION CENTRAL  ...
# 1634656                          ADMINISTRACION CENTRAL  ...
# 1259481                          ADMINISTRACION CENTRAL  ...
# 1591439  UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 1432168                          ADMINISTRACION CENTRAL  ...
# 1006203                          ADMINISTRACION CENTRAL  ...
# 1221827                          ADMINISTRACION CENTRAL  ...
# 1193932  UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 1411140  UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 979924   UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 1000868                          ADMINISTRACION CENTRAL  ...
# 793780                           ADMINISTRACION CENTRAL  ...
# 1791803                                           otros  ...
# 813849                           ADMINISTRACION CENTRAL  ...
# 665956                           ADMINISTRACION CENTRAL  ...
# 445397                           ADMINISTRACION CENTRAL  ...
# 785886   UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 259807                           ADMINISTRACION CENTRAL  ...
# 580094   UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 625436                           ADMINISTRACION CENTRAL  ...
# 412698   UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 445048                           ADMINISTRACION CENTRAL  ...
# 215710   UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 1591459                                     CONTRALORIA  ...
# 1791410                                           otros  ...
# 1791512                                           otros  ...
# 66923                            ADMINISTRACION CENTRAL  ...
# 232311                           ADMINISTRACION CENTRAL  ...
# 1591407                    PERSONERIA - SOLO MUNICIPIOS  ...
# 1629774                          ADMINISTRACION CENTRAL  ...
#
#         Fuente Financiación Presupuesto Inicial  Presupuesto Definitivo  \
# 1591537               otros        2.919074e+12            2.821599e+12
# 1411147               otros        2.917373e+12            3.041927e+12
# 980032                otros        2.902548e+12            2.835075e+12
# 785999                otros        2.805296e+12            2.813175e+12
# 1194027               otros        2.408128e+12            2.362667e+12
# 1791120                            2.362353e+12            2.109536e+12
# 580210                otros        1.880046e+12            1.878602e+12
# 412848                otros        1.821922e+12            2.103799e+12
# 215835                otros        1.637485e+12            1.631935e+12
# 3529                  otros        1.472001e+12            1.460602e+12
# 1800069                            7.075573e+11            6.899295e+11
# 1630573               otros        6.490121e+11            6.390277e+11
# 1630926               otros        6.473226e+11            6.156091e+11
# 1424576               otros        6.238761e+11            5.810149e+11
# 1427491               otros        6.103184e+11            6.306963e+11
# 1221548               otros        5.844919e+11            5.515953e+11
# 1007207               otros        5.615214e+11            5.109218e+11
# 1263047               otros        5.525794e+11            5.340436e+11
# 793492                otros        5.229683e+11            4.940387e+11
# 445717                otros        5.059796e+11            4.024076e+11
# 634090                otros        5.039131e+11            4.489479e+11
# 273839                otros        4.885969e+11            5.865477e+11
# 1034439               otros        4.870435e+11            5.399210e+11
# 231961                otros        4.465433e+11            3.693853e+11
# 624827                otros        4.411044e+11            4.504874e+11
# 66206                 otros        4.196352e+11            3.882028e+11
# 1439876               otros        4.157400e+11            4.082425e+11
# 470808                otros        4.150844e+11            4.282335e+11
# 848453                otros        4.054105e+11            4.496173e+11
# 65916                 otros        3.923771e+11            4.221270e+11
# 1632991               otros        3.564032e+11            4.063888e+11
# 1634656               otros        3.517174e+11            3.426522e+11
# 1259481               otros        3.360607e+11            3.565905e+11
# 1591439               otros        3.125439e+11            3.124938e+11
# 1432168               otros        2.860429e+11            3.150328e+11
# 1006203               otros        2.701814e+11            3.127619e+11
# 1221827               otros        2.661019e+11            2.843852e+11
# 1193932               otros        2.433347e+11            2.433347e+11
# 1411140               otros        2.412322e+11            2.403592e+11
# 979924                otros        2.350612e+11            2.350387e+11
# 1000868               otros        2.347685e+11            2.534872e+11
# 793780                otros        2.322767e+11            2.544709e+11
# 1791803                            2.313530e+11            2.313530e+11
# 813849                otros        2.265332e+11            2.683962e+11
# 665956                otros        2.254012e+11            2.217626e+11
# 445397                otros        2.165147e+11            2.214795e+11
# 785886                otros        2.131217e+11            2.130405e+11
# 259807                otros        2.110354e+11            2.238024e+11
# 580094                otros        1.980202e+11            1.978578e+11
# 625436                otros        1.936982e+11            2.142455e+11
# 412698                otros        1.926151e+11            1.926132e+11
# 445048                otros        1.798734e+11            1.826891e+11
# 215710                otros        1.680671e+11            1.680671e+11
# 1591459               otros        1.591188e+11            1.591188e+11
# 1791410                            1.589676e+11            1.645143e+11
# 1791512                            1.544265e+11            1.556265e+11
# 66923                 otros        1.541935e+11            1.548495e+11
# 232311                otros        1.538184e+11            1.619855e+11
# 1591407               otros        1.524852e+11            1.524852e+11
# 1629774               otros        1.508462e+11            1.404146e+11
#
#           Compromisos  Obligaciones         Pagos     Año  Nivel concepto  \
# 1591537  2.467069e+12  2.347192e+12  2.347192e+12  2020.0             1.0
# 1411147  2.822659e+12  2.749884e+12  2.749884e+12  2019.0             1.0
# 980032   2.589441e+12  2.442784e+12  2.442784e+12  2017.0             1.0
# 785999   2.581062e+12  2.477827e+12  2.477827e+12  2016.0             1.0
# 1194027  2.203927e+12  2.146354e+12  2.146354e+12  2018.0             1.0
# 1791120  1.910392e+12  1.843493e+12  1.843493e+12  2021.0             1.0
# 580210   1.701374e+12  1.653697e+12  1.653697e+12  2015.0             1.0
# 412848   1.925767e+12  1.861874e+12  1.861874e+12  2014.0             1.0
# 215835   1.462142e+12  1.400935e+12  1.400515e+12  2013.0             1.0
# 3529     1.335949e+12  1.277683e+12  1.277683e+12  2012.0             1.0
# 1800069  6.450851e+11  6.354152e+11  6.042577e+11  2021.0             1.0
# 1630573  5.646098e+11  5.595664e+11  5.155858e+11  2020.0             1.0
# 1630926  5.789263e+11  5.789263e+11  5.789043e+11  2020.0             1.0
# 1424576  5.710758e+11  5.710758e+11  5.709142e+11  2019.0             1.0
# 1427491  6.006911e+11  5.949757e+11  5.771124e+11  2019.0             1.0
# 1221548  5.410275e+11  5.410275e+11  5.408419e+11  2018.0             1.0
# 1007207  5.046109e+11  5.046109e+11  5.043661e+11  2017.0             1.0
# 1263047  5.046484e+11  5.033199e+11  3.821100e+11  2018.0             1.0
# 793492   4.882371e+11  4.882371e+11  4.882203e+11  2016.0             1.0
# 445717   3.972076e+11  3.972076e+11  3.971425e+11  2014.0             1.0
# 634090   4.455921e+11  4.455921e+11  4.453114e+11  2015.0             1.0
# 273839   5.114060e+11  5.085907e+11  4.650802e+11  2013.0             1.0
# 1034439  5.140115e+11  5.132020e+11  4.058255e+11  2017.0             1.0
# 231961   3.621940e+11  3.621940e+11  3.621184e+11  2013.0             1.0
# 624827   4.173886e+11  4.147715e+11  3.852777e+11  2015.0             1.0
# 66206    3.875040e+11  3.825015e+11  3.806469e+11  2012.0             1.0
# 1439876  4.001835e+11  3.552346e+11  3.388302e+11  2019.0             1.0
# 470808   3.937712e+11  3.897052e+11  3.461511e+11  2014.0             1.0
# 848453   4.312771e+11  4.287943e+11  4.104217e+11  2016.0             1.0
# 65916    3.934140e+11  3.893875e+11  3.751482e+11  2012.0             1.0
# 1632991  3.775818e+11  3.506611e+11  3.244926e+11  2020.0             1.0
# 1634656  2.857498e+11  2.763703e+11  2.644610e+11  2020.0             1.0
# 1259481  3.460982e+11  3.414657e+11  3.404022e+11  2018.0             1.0
# 1591439  2.146991e+11  2.115961e+11  2.115961e+11  2020.0             1.0
# 1432168  2.823001e+11  2.694690e+11  2.504422e+11  2019.0             1.0
# 1006203  2.952262e+11  2.893230e+11  2.561182e+11  2017.0             1.0
# 1221827  2.626437e+11  2.340534e+11  2.209871e+11  2018.0             1.0
# 1193932  2.378192e+11  2.185487e+11  2.185487e+11  2018.0             1.0
# 1411140  2.265193e+11  2.255034e+11  2.255034e+11  2019.0             1.0
# 979924   2.155998e+11  2.062458e+11  2.062458e+11  2017.0             1.0
# 1000868  2.252783e+11  2.194842e+11  2.096840e+11  2017.0             1.0
# 793780   2.211399e+11  2.211399e+11  2.091100e+11  2016.0             1.0
# 1791803  1.997486e+11  1.975836e+11  1.975836e+11  2021.0             1.0
# 813849   2.669340e+11  2.669340e+11  2.569355e+11  2016.0             1.0
# 665956   2.182128e+11  2.182128e+11  2.089084e+11  2015.0             1.0
# 445397   2.197279e+11  2.197279e+11  2.154929e+11  2014.0             1.0
# 785886   2.114283e+11  1.906809e+11  1.906809e+11  2016.0             1.0
# 259807   2.227475e+11  2.227475e+11  2.181787e+11  2013.0             1.0
# 580094   1.770253e+11  1.271354e+11  1.271354e+11  2015.0             1.0
# 625436   1.916682e+11  1.916682e+11  1.888962e+11  2015.0             1.0
# 412698   1.518541e+11  1.352463e+11  1.352463e+11  2014.0             1.0
# 445048   1.595639e+11  1.595639e+11  1.554780e+11  2014.0             1.0
# 215710   1.526754e+11  1.498343e+11  1.498343e+11  2013.0             1.0
# 1591459  1.583678e+11  1.564046e+11  1.564046e+11  2020.0             1.0
# 1791410  1.638823e+11  1.622384e+11  1.622384e+11  2021.0             1.0
# 1791512  1.551150e+11  1.532454e+11  1.532454e+11  2021.0             1.0
# 66923    1.327070e+11  1.302316e+11  1.302316e+11  2012.0             1.0
# 232311   1.447111e+11  1.447111e+11  1.311457e+11  2013.0             1.0
# 1591407  1.516686e+11  1.459540e+11  1.459540e+11  2020.0             1.0
# 1629774  1.215874e+11  1.214874e+11  1.214176e+11  2020.0             1.0
#
#                 key categoria
# 1591537  11001_2020       ESP
# 1411147  11001_2019       ESP
# 980032   11001_2017       ESP
# 785999   11001_2016       ESP
# 1194027  11001_2018       ESP
# 1791120  11001_2021       ESP
# 580210   11001_2015       ESP
# 412848   11001_2014       ESP
# 215835   11001_2013       ESP
# 3529     11001_2012       ESP
# 1800069  76001_2021       ESP
# 1630573  76001_2020       ESP
# 1630926   5001_2020       ESP
# 1424576   5001_2019       ESP
# 1427491  76001_2019       ESP
# 1221548   5001_2018       ESP
# 1007207   5001_2017       ESP
# 1263047  76001_2018       ESP
# 793492    5001_2016       ESP
# 445717    5001_2014       ESP
# 634090    5001_2015       ESP
# 273839   76001_2013       ESP
# 1034439  76001_2017       ESP
# 231961    5001_2013       ESP
# 624827   76001_2015       ESP
# 66206     5001_2012       ESP
# 1439876   8001_2019       ESP
# 470808   76001_2014       ESP
# 848453   76001_2016       ESP
# 65916    76001_2012       ESP
# 1632991   8001_2020       ESP
# 1634656  13001_2020       ESP
# 1259481   8001_2018       ESP
# 1591439  11001_2020       ESP
# 1432168  13001_2019       ESP
# 1006203   8001_2017       ESP
# 1221827  13001_2018       ESP
# 1193932  11001_2018       ESP
# 1411140  11001_2019       ESP
# 979924   11001_2017       ESP
# 1000868  13001_2017       ESP
# 793780   13001_2016       ESP
# 1791803  11001_2021       ESP
# 813849    8001_2016       ESP
# 665956    8001_2015       ESP
# 445397    8001_2014       ESP
# 785886   11001_2016       ESP
# 259807    8001_2013       ESP
# 580094   11001_2015       ESP
# 625436   13001_2015       ESP
# 412698   11001_2014       ESP
# 445048   13001_2014       ESP
# 215710   11001_2013       ESP
# 1591459  11001_2020       ESP
# 1791410  11001_2021       ESP
# 1791512  11001_2021       ESP
# 66923    13001_2012       ESP
# 232311   13001_2013       ESP
# 1591407  11001_2020       ESP
# 1629774  66001_2020         1
#
# [60 rows x 21 columns]

# %% [markdown]
# We see that when analyzing the results of the filter we see that the municipalities whose values among the cats by category were similar are not affected, as shown in dataFrames **A** and **B**. Whose pre-filter and post-filter values remained the same.

# %%
A = nivel_1_limpio[(nivel_1_limpio['Cód. DANE Municipio'] == 5467) & (nivel_1_limpio['Año'] == 2019)].sort_index()
A
# Out:
#           Código FUT Nombre Entidad  Cód. DANE Departamento  \
# 1440274  216705467.0     MONTEBELLO                     5.0
# 1440275  216705467.0     MONTEBELLO                     5.0
# 1440279  216705467.0     MONTEBELLO                     5.0
# 1440280  216705467.0     MONTEBELLO                     5.0
#
#         Nombre DANE Departamento  Cód. DANE Municipio Nombre DANE Municipio  \
# 1440274                ANTIOQUIA               5467.0            MONTEBELLO
# 1440275                ANTIOQUIA               5467.0            MONTEBELLO
# 1440279                ANTIOQUIA               5467.0            MONTEBELLO
# 1440280                ANTIOQUIA               5467.0            MONTEBELLO
#
#         Código Concepto                        Concepto  \
# 1440274               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1440275               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1440279               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1440280               1  TOTAL GASTOS DE FUNCIONAMIENTO
#
#         Código Unidad Ejecutora              Unidad Ejecutora  ...  \
# 1440274                     6.0       SECRETARIA DE EDUCACION  ...
# 1440275                     5.0  PERSONERIA - SOLO MUNICIPIOS  ...
# 1440279                     2.0     CONCEJO - SOLO MUNICIPIOS  ...
# 1440280                     1.0        ADMINISTRACION CENTRAL  ...
#
#         Fuente Financiación Presupuesto Inicial  Presupuesto Definitivo  \
# 1440274               otros        4.841607e+07            4.841607e+07
# 1440275               otros        7.580140e+07            7.580140e+07
# 1440279               otros        1.272309e+08            1.272309e+08
# 1440280               otros        1.593444e+09            1.593444e+09
#
#          Compromisos  Obligaciones  Pagos     Año  Nivel concepto        key  \
# 1440274          0.0           0.0    0.0  2019.0             1.0  5467_2019
# 1440275          0.0           0.0    0.0  2019.0             1.0  5467_2019
# 1440279          0.0           0.0    0.0  2019.0             1.0  5467_2019
# 1440280          0.0           0.0    0.0  2019.0             1.0  5467_2019
#
#         categoria
# 1440274         6
# 1440275         6
# 1440279         6
# 1440280         6
#
# [4 rows x 21 columns]

# %%
B = nivel_1_limpio_categorias[(nivel_1_limpio_categorias['Cód. DANE Municipio'] == 5467) & (nivel_1_limpio_categorias['Año'] == 2019)].sort_index()
B
# Out:
#           Código FUT Nombre Entidad  Cód. DANE Departamento  \
# 1440274  216705467.0     MONTEBELLO                     5.0
# 1440275  216705467.0     MONTEBELLO                     5.0
# 1440279  216705467.0     MONTEBELLO                     5.0
# 1440280  216705467.0     MONTEBELLO                     5.0
#
#         Nombre DANE Departamento  Cód. DANE Municipio Nombre DANE Municipio  \
# 1440274                ANTIOQUIA               5467.0            MONTEBELLO
# 1440275                ANTIOQUIA               5467.0            MONTEBELLO
# 1440279                ANTIOQUIA               5467.0            MONTEBELLO
# 1440280                ANTIOQUIA               5467.0            MONTEBELLO
#
#         Código Concepto                        Concepto  \
# 1440274               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1440275               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1440279               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 1440280               1  TOTAL GASTOS DE FUNCIONAMIENTO
#
#         Código Unidad Ejecutora              Unidad Ejecutora  ...  \
# 1440274                     6.0       SECRETARIA DE EDUCACION  ...
# 1440275                     5.0  PERSONERIA - SOLO MUNICIPIOS  ...
# 1440279                     2.0     CONCEJO - SOLO MUNICIPIOS  ...
# 1440280                     1.0        ADMINISTRACION CENTRAL  ...
#
#         Fuente Financiación Presupuesto Inicial  Presupuesto Definitivo  \
# 1440274               otros        4.841607e+07            4.841607e+07
# 1440275               otros        7.580140e+07            7.580140e+07
# 1440279               otros        1.272309e+08            1.272309e+08
# 1440280               otros        1.593444e+09            1.593444e+09
#
#          Compromisos  Obligaciones  Pagos     Año  Nivel concepto        key  \
# 1440274          0.0           0.0    0.0  2019.0             1.0  5467_2019
# 1440275          0.0           0.0    0.0  2019.0             1.0  5467_2019
# 1440279          0.0           0.0    0.0  2019.0             1.0  5467_2019
# 1440280          0.0           0.0    0.0  2019.0             1.0  5467_2019
#
#         categoria
# 1440274         6
# 1440275         6
# 1440279         6
# 1440280         6
#
# [4 rows x 21 columns]

# %% [markdown]
# On the other hand for the municipalities that presented ouliers we see that the values are rewritten to adjust to the real values, because under no concept it is expected that the municpios of the category **6** (The inferior category) as the minicipality of **TOCA** has equal expenses $211.400.500.000$ pesos, in public services.

# %%
nivel_1_limpio[(nivel_1_limpio['Nombre DANE Municipio'] == 'TOCA') & (nivel_1_limpio['Año'] == 2016)].sort_index()
# Out:
#          Código FUT Nombre Entidad  Cód. DANE Departamento  \
# 855617  211415814.0           TOCA                    15.0
# 855653  211415814.0           TOCA                    15.0
# 855657  211415814.0           TOCA                    15.0
# 855691  211415814.0           TOCA                    15.0
#
#        Nombre DANE Departamento  Cód. DANE Municipio Nombre DANE Municipio  \
# 855617                   BOYACA              15814.0                  TOCA
# 855653                   BOYACA              15814.0                  TOCA
# 855657                   BOYACA              15814.0                  TOCA
# 855691                   BOYACA              15814.0                  TOCA
#
#        Código Concepto                        Concepto  \
# 855617               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 855653               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 855657               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 855691               1  TOTAL GASTOS DE FUNCIONAMIENTO
#
#        Código Unidad Ejecutora  \
# 855617                     8.0
# 855653                     5.0
# 855657                     2.0
# 855691                     1.0
#
#                                       Unidad Ejecutora  ...  \
# 855617  UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 855653                    PERSONERIA - SOLO MUNICIPIOS  ...
# 855657                       CONCEJO - SOLO MUNICIPIOS  ...
# 855691                          ADMINISTRACION CENTRAL  ...
#
#        Fuente Financiación Presupuesto Inicial  Presupuesto Definitivo  \
# 855617               otros        2.114005e+11            2.220757e+11
# 855653               otros        1.005186e+09            1.005186e+09
# 855657               otros        1.398705e+09            1.398705e+09
# 855691               otros        7.206505e+09            7.206505e+09
#
#          Compromisos  Obligaciones         Pagos     Año  Nivel concepto  \
# 855617  2.049312e+11  2.049312e+11  2.049312e+11  2016.0             1.0
# 855653  9.568745e+08  9.568745e+08  9.568745e+08  2016.0             1.0
# 855657  1.372214e+09  1.372214e+09  1.372214e+09  2016.0             1.0
# 855691  6.601136e+09  6.601136e+09  6.601136e+09  2016.0             1.0
#
#                key categoria
# 855617  15814_2016         6
# 855653  15814_2016         6
# 855657  15814_2016         6
# 855691  15814_2016         6
#
# [4 rows x 21 columns]

# %%
nivel_1_limpio_categorias[(nivel_1_limpio_categorias['Nombre DANE Municipio'] == 'TOCA') & (nivel_1_limpio_categorias['Año'] == 2016)].sort_index()
# Out:
#          Código FUT Nombre Entidad  Cód. DANE Departamento  \
# 855617  211415814.0           TOCA                    15.0
# 855653  211415814.0           TOCA                    15.0
# 855657  211415814.0           TOCA                    15.0
# 855691  211415814.0           TOCA                    15.0
#
#        Nombre DANE Departamento  Cód. DANE Municipio Nombre DANE Municipio  \
# 855617                   BOYACA              15814.0                  TOCA
# 855653                   BOYACA              15814.0                  TOCA
# 855657                   BOYACA              15814.0                  TOCA
# 855691                   BOYACA              15814.0                  TOCA
#
#        Código Concepto                        Concepto  \
# 855617               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 855653               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 855657               1  TOTAL GASTOS DE FUNCIONAMIENTO
# 855691               1  TOTAL GASTOS DE FUNCIONAMIENTO
#
#        Código Unidad Ejecutora  \
# 855617                     8.0
# 855653                     5.0
# 855657                     2.0
# 855691                     1.0
#
#                                       Unidad Ejecutora  ...  \
# 855617  UNIDAD DE SERVICIOS PUBLICOS - SOLO MUNICIPIOS  ...
# 855653                    PERSONERIA - SOLO MUNICIPIOS  ...
# 855657                       CONCEJO - SOLO MUNICIPIOS  ...
# 855691                          ADMINISTRACION CENTRAL  ...
#
#        Fuente Financiación Presupuesto Inicial  Presupuesto Definitivo  \
# 855617               otros          21140053.3              22207573.3
# 855653               otros         100518600.0             100518600.0
# 855657               otros          13987047.8              13987047.8
# 855691               otros         720650519.0             720650519.0
#
#         Compromisos  Obligaciones        Pagos     Año  Nivel concepto  \
# 855617   20493123.8    20493123.8   20493123.8  2016.0             1.0
# 855653   95687449.0    95687449.0   95687449.0  2016.0             1.0
# 855657   13722136.1    13722136.1   13722136.1  2016.0             1.0
# 855691  660113618.0   660113618.0  660113618.0  2016.0             1.0
#
#                key categoria
# 855617  15814_2016         6
# 855653  15814_2016         6
# 855657  15814_2016         6
# 855691  15814_2016         6
#
# [4 rows x 21 columns]

# %% [markdown]
# ## 6. Dataexporting

# %% [markdown]
# When checking the results, this change is applied to level 2 and 3 concepts.

# %%
nivel_1_limpio_categorias.to_csv('Gatos_totales_nivel_1_limpio_categorias.csv', encoding = 'utf-8', index = False)

# %% [markdown]
# nivel_2_limpio_categorias = clean_ouliers_by_category(nivel_2_limpio)
# nivel_2_limpio_categorias.to_csv('Gatos_totales_nivel_2_limpio_categorias.csv', encoding = 'utf-8', index = False)

# %% [markdown]
# nivel_3_limpio_categorias = clean_ouliers_by_category(nivel_3_limpio)
# nivel_3_limpio_categorias.to_csv('Gatos_totales_nivel_3_limpio_categorias.csv', encoding = 'utf-8', index = False)
